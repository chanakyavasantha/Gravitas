# %% [markdown]
# # This notebook can be used for loading model

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import glob
import time
import plotly.express as px
import plotly.graph_objects as go
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
import numpy as np
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout
from keras.optimizers import Adam
from sklearn.metrics import classification_report
from tensorflow import keras
# Out:
# 2023-09-19 19:03:56.318674: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-09-19 19:03:57.034630: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
reconstructed_model = keras.models.load_model("/home/itachi/Documents/best_model.h5")
# Out:
# 2023-09-19 19:03:57.721076: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-09-19 19:03:57.742501: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# ...

# %%
reconstructed_model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ...
#  input_1 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  zero_padding2d (ZeroPaddin  (None, 230, 230, 3)          0         ['input_1[0][0]']
#  g2D)
#
#  conv1 (Conv2D)              (None, 112, 112, 64)         9472      ['zero_padding2d[0][0]']
#
#  bn_conv1 (BatchNormalizati  (None, 112, 112, 64)         256       ['conv1[0][0]']
#  on)
#
#  activation (Activation)     (None, 112, 112, 64)         0         ['bn_conv1[0][0]']
#
#  max_pooling2d (MaxPooling2  (None, 55, 55, 64)           0         ['activation[0][0]']
#  D)
#
#  res2a_branch2a (Conv2D)     (None, 55, 55, 64)           4160      ['max_pooling2d[0][0]']
#
#  bn2a_branch2a (BatchNormal  (None, 55, 55, 64)           256       ['res2a_branch2a[0][0]']
#  ization)
#
# ...

# %%
keras.utils.plot_model(reconstructed_model, show_shapes=True)

# %% [markdown]
# ## For seeing model statics from tensor board saved logs dierectory

# %%
# !python -m tensorboard.main --logdir=/home/itachi/DataspellProjects/Project_LifeMeter/Life/logs_TrimmedFinal
# Out:
# /bin/bash: /home/itachi/anaconda3/envs/Gpu/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# 2023-09-19 19:04:01.951940: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-09-19 19:04:02.508722: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-09-19 19:04:03.304320: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# ...
